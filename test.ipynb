# %%
import os
from dotenv import load_dotenv
from azure.core.credentials import AzureKeyCredential
from azure.search.documents import SearchClient
from sentence_transformers import SentenceTransformer

load_dotenv()
key = os.getenv("AZURE_SEARCH_KEY")
service = os.getenv("AZURE_SEARCH_SERVICE")
index_name = os.getenv("AZURE_SEARCH_INDEX")

client = SearchClient(
    endpoint=f"https://{service}.search.windows.net",
    index_name=index_name,
    credential=AzureKeyCredential(key)
)
embedding= SentenceTransformer("intfloat/e5-base-v2")

from azure.search.documents.models import VectorizedQuery

query = "What is Graph Neural Networks?"

vector_query = VectorizedQuery(
    vector=embedding.encode(query).tolist(),
    k_nearest_neighbors=3,
    fields="contentVector"
)

results = client.search(
    search_text="Graph Neural Networks",  
    vector_queries=[vector_query],
    select=["id", "content", "source"]
)

for r in results:
    print(f"ID: {r['id']} | Source: {r.get('source')} | Content: {r['content'][:200]}...")
# Out:
# ID: fa8761f2-57ee-427d-b506-fa4ff45bba21 | Source: Benchmarking graph neural networks.pdf | Content: Preface
# The field of graph neural networks (GNNs) has seen rapid and incredible strides over
# the recent years. Graph neural networks, also known as deep learning on graphs,
# graph representation learni...
# ID: fcc8ad01-e66f-490a-a4a6-79f0c83bbe35 | Source: Continuous graph neural networks.pdf | Content: Preface
# The field of graph neural networks (GNNs) has seen rapid and incredible strides over
# the recent years. Graph neural networks, also known as deep learning on graphs,
# graph representation learni...
# ID: a0d22649-4b5f-4043-a710-f75219e0a545 | Source: Graph neural networks.pdf | Content: Preface
# The field of graph neural networks (GNNs) has seen rapid and incredible strides over
# the recent years. Graph neural networks, also known as deep learning on graphs,
# graph representation learni...
# ID: a08ce274-610c-4512-ac81-0eeddb05b8e0 | Source: Benchmarking graph neural networks.pdf | Content: different directions: i) Graph Neural Networks Methods; ii) Theoretical understand-
# ing of Graph Neural Networks; iii) Scalability of Graph Neural Networks; iv) In-
# terpretability of Graph Neural Netw...
# ID: 629db721-1213-4d50-b04e-c9254938c3f7 | Source: Continuous graph neural networks.pdf | Content: different directions: i) Graph Neural Networks Methods; ii) Theoretical understand-
# ing of Graph Neural Networks; iii) Scalability of Graph Neural Networks; iv) In-
# terpretability of Graph Neural Netw...
# ID: 0d1ef4aa-a9d4-43f5-b14c-4542199a30dd | Source: Graph neural networks.pdf | Content: different directions: i) Graph Neural Networks Methods; ii) Theoretical understand-
# ing of Graph Neural Networks; iii) Scalability of Graph Neural Networks; iv) In-
# terpretability of Graph Neural Netw...
# ID: e9e018f9-e24f-48de-a0a0-a42b858610ba | Source: Benchmarking graph neural networks.pdf | Content: 3.2.3 Graph Neural Networks: Applications . . . . . . . . . . . . . . . . 33
# 3.2.4 Graph Neural Networks: Organization . . . . . . . . . . . . . . . . 35
# 3.3 Summary . . . . . . . . . . . . . . . . . ...
# ID: 213051a1-e7ee-4888-b33c-99a5a5898b9e | Source: Continuous graph neural networks.pdf | Content: 3.2.3 Graph Neural Networks: Applications . . . . . . . . . . . . . . . . 33
# 3.2.4 Graph Neural Networks: Organization . . . . . . . . . . . . . . . . 35
# 3.3 Summary . . . . . . . . . . . . . . . . . ...
# ID: ae11b13e-d6c5-49e6-b0d2-7b2207e6c2c5 | Source: Graph neural networks.pdf | Content: 3.2.3 Graph Neural Networks: Applications . . . . . . . . . . . . . . . . 33
# 3.2.4 Graph Neural Networks: Organization . . . . . . . . . . . . . . . . 35
# 3.3 Summary . . . . . . . . . . . . . . . . . ...
# ID: 2dda624c-da88-4e7c-8d07-8f70537c80e8 | Source: Benchmarking graph neural networks.pdf | Content: xx Contents
# 3 Graph
# Neural Networks . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .27
# Lingfei Wu, Peng Cui, Jian Pei, Liang Zhao and Le Song
# 3.1 Graph Neural Networks: An I...
# ID: b0f0d31d-3aa0-49a4-9527-adb7c5ed77ad | Source: Continuous graph neural networks.pdf | Content: xx Contents
# 3 Graph
# Neural Networks . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .27
# Lingfei Wu, Peng Cui, Jian Pei, Liang Zhao and Le Song
# 3.1 Graph Neural Networks: An I...
# ID: 54f359a8-445a-4ee1-b26f-d2b5b1a2f4fa | Source: Graph neural networks.pdf | Content: xx Contents
# 3 Graph
# Neural Networks . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .27
# Lingfei Wu, Peng Cui, Jian Pei, Liang Zhao and Le Song
# 3.1 Graph Neural Networks: An I...
# ID: 2f8b6b3d-70d8-4242-88bb-8dd5632d772f | Source: Graph neural networks in IoT_ A survey.pdf | Content: into four categories, namely recurrent graph neural networks, convolutional graph neural networks, graph
# autoencoders, and spatial-temporal graph neural networks. Similarly, Wu et al. [283] categorize...
# ID: 31f262a9-6740-4b30-b1d3-1c37c2c7d483 | Source: Benchmarking graph neural networks.pdf | Content: 4.2.4 Neural Message Passing Networks . . . . . . . . . . . . . . . . . . . 48
# 4.2.5 Continuous Graph Neural Networks . . . . . . . . . . . . . . . . . . 48
# 4.2.6 Multi-Scale Spectral Graph Convolutio...
# ID: 9555f80f-152c-45cf-b951-78c107e06620 | Source: Continuous graph neural networks.pdf | Content: 4.2.4 Neural Message Passing Networks . . . . . . . . . . . . . . . . . . . 48
# 4.2.5 Continuous Graph Neural Networks . . . . . . . . . . . . . . . . . . 48
# 4.2.6 Multi-Scale Spectral Graph Convolutio...
# ID: 05f914a0-03fc-4a1b-a54d-6ad0a14df425 | Source: Graph neural networks.pdf | Content: 4.2.4 Neural Message Passing Networks . . . . . . . . . . . . . . . . . . . 48
# 4.2.5 Continuous Graph Neural Networks . . . . . . . . . . . . . . . . . . 48
# 4.2.6 Multi-Scale Spectral Graph Convolutio...
# ID: f34ac9aa-c397-4467-ae74-cc764c837c48 | Source: Benchmarking graph neural networks.pdf | Content: 8.6 Summary . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 175
# Part III Frontiers of Graph Neural Networks
# 9 Graph Neural Networks: Graph Classificatio...
# ID: 0da5774e-851b-4f1f-b6ba-a878bb6f2264 | Source: Continuous graph neural networks.pdf | Content: 8.6 Summary . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 175
# Part III Frontiers of Graph Neural Networks
# 9 Graph Neural Networks: Graph Classificatio...
# ID: 27d86a74-1ce3-4050-b75d-e2a3567e2135 | Source: Graph neural networks.pdf | Content: 8.6 Summary . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 175
# Part III Frontiers of Graph Neural Networks
# 9 Graph Neural Networks: Graph Classificatio...
# ID: 645313fe-eaf2-4c82-8e47-fba315ffd939 | Source: Benchmarking graph neural networks.pdf | Content: Jian Tang and Renjie Liao
# 4.1 Background and Problem Definition . . . . . . . . . . . . . . . . . . . . . . . . . 41
# 4.2 Supervised Graph Neural Networks . . . . . . . . . . . . . . . . . . . . . . . ...
# ID: 8b68422d-6a4e-4463-aa5b-b0c78de6fbf2 | Source: Continuous graph neural networks.pdf | Content: Jian Tang and Renjie Liao
# 4.1 Background and Problem Definition . . . . . . . . . . . . . . . . . . . . . . . . . 41
# 4.2 Supervised Graph Neural Networks . . . . . . . . . . . . . . . . . . . . . . . ...
# ID: 5a4fffc6-2528-48c9-90bd-b68cd9e68428 | Source: Graph neural networks.pdf | Content: Jian Tang and Renjie Liao
# 4.1 Background and Problem Definition . . . . . . . . . . . . . . . . . . . . . . . . . 41
# 4.2 Supervised Graph Neural Networks . . . . . . . . . . . . . . . . . . . . . . . ...
# ID: 9edc8829-c440-4b45-a5ab-38fee90a3911 | Source: Benchmarking graph neural networks.pdf | Content: 5.3 The Power of Message Passing Graph Neural Networks . . . . . . . . . 70
# 5.3.1 Preliminaries: Neural Networks for Sets . . . . . . . . . . . . . . . 70
# 5.3.2 Message Passing Graph Neural Networks ....
# ID: e834c389-dcd4-43ff-83c5-131e9f2baadc | Source: Continuous graph neural networks.pdf | Content: 5.3 The Power of Message Passing Graph Neural Networks . . . . . . . . . 70
# 5.3.1 Preliminaries: Neural Networks for Sets . . . . . . . . . . . . . . . 70
# 5.3.2 Message Passing Graph Neural Networks ....
# ID: efa3a137-22f7-4ced-9567-6b724e0cf9ab | Source: Graph neural networks.pdf | Content: 5.3 The Power of Message Passing Graph Neural Networks . . . . . . . . . 70
# 5.3.1 Preliminaries: Neural Networks for Sets . . . . . . . . . . . . . . . 70
# 5.3.2 Message Passing Graph Neural Networks ....
# ID: 51851c60-b131-467f-9bae-60bf01f532ee | Source: Benchmarking graph neural networks.pdf | Content: function.
# 4.2.5 Continuous Graph Neural Networks
# The above graph neural networks iteratively update the node representations with
# different kinds of graph convolutional layers. Essentially, these appr...
# ID: 41f9b2d3-ff54-441f-b6f2-6d196d6e9c40 | Source: Continuous graph neural networks.pdf | Content: function.
# 4.2.5 Continuous Graph Neural Networks
# The above graph neural networks iteratively update the node representations with
# different kinds of graph convolutional layers. Essentially, these appr...
# ID: 38d3dd51-5eea-4fb2-b935-ddd18f7d5e54 | Source: Graph neural networks.pdf | Content: function.
# 4.2.5 Continuous Graph Neural Networks
# The above graph neural networks iteratively update the node representations with
# different kinds of graph convolutional layers. Essentially, these appr...
# ID: 3c3007e9-0792-48a8-b684-07f44ad00b74 | Source: Artificial intelligence in cancer target identification and drug discovery.pdf | Content: in the network.
# Currently, arti ﬁcial intelligence biology analysis has bene-
# ﬁted from the utilization of graph-based neural networks
# instead of commonly used non-graph neural networks
# such as CNN
# 17...
# ID: 1d578540-67dd-4ed6-abd2-4298fbd184fa | Source: Benchmarking graph neural networks.pdf | Content: 27
# Graph Neural Networks in Urban Intelligence 581
# tion and knowledge in the data, and plenty of techniques are developed to analyze
# the urban graph data.
# Graph Neural Networks (GNNs) are naturally em...
# ID: 6a74a5dc-398b-41cf-b1b8-9a908d166823 | Source: Continuous graph neural networks.pdf | Content: 27
# Graph Neural Networks in Urban Intelligence 581
# tion and knowledge in the data, and plenty of techniques are developed to analyze
# the urban graph data.
# Graph Neural Networks (GNNs) are naturally em...
# ID: 1cc18460-f61c-44e3-a9d6-3d8ba217df67 | Source: Artificial intelligence in cancer target identification and drug discovery.pdf | Content: targets. Second, we present the artiﬁcial intelligence applications
# Fig. 8 The illustration of graph-based neural networks for ML-based biology analysis.The graph-based neural networks take the topolo...
# ID: be38cf9b-0116-47cc-ba97-e83646d12eba | Source: Artificial intelligence in cancer target identification and drug discovery.pdf | Content: ogy. Figure 8 illustrates the basic ﬂowchart of graph-based
# neural networks for the investigation of different properties of
# biological networks.
# There are two advantages in using graph-based neural
# n...
# ID: 06373392-b3c2-4700-866c-a8aff059c5b7 | Source: A survey on oversmoothing in graph neural networks.pdf | Content: class of graph-learning models as continuous-time GNNs. Early examples of continuous-time GNNs include Graph
# Neural Ordinary Differential Equations (GDEs) (Poli et al., 2019) and Continuous Graph Neur...
# ID: c65995af-ff01-46e6-b9a6-3229f2827448 | Source: Benchmarking graph neural networks.pdf | Content: • Part II: Foundations. These chapters describe the foundations of the graph neu-
# ral networks by introducing the properties of graph neural networks as well as
# several fundamental problems in this li...
# ID: 6207a73f-84ab-4efa-b911-ddaf29eebb0d | Source: Continuous graph neural networks.pdf | Content: • Part II: Foundations. These chapters describe the foundations of the graph neu-
# ral networks by introducing the properties of graph neural networks as well as
# several fundamental problems in this li...
# ID: 7faeccb0-8303-48aa-928b-2cac9a86b584 | Source: Graph neural networks.pdf | Content: • Part II: Foundations. These chapters describe the foundations of the graph neu-
# ral networks by introducing the properties of graph neural networks as well as
# several fundamental problems in this li...
# ID: 445dbcb0-1bc8-430e-b33f-b1670c0c2293 | Source: Benchmarking graph neural networks.pdf | Content: 15.3.2 Types of Evolution . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 333
# 15.3.3 Prediction Problems, Interpolation, and Extrapolation . . . 334
# 15.4 Modeling Dynamic Graphs with G...
# ID: 9af8d01c-fff5-4db0-ad8c-a06f56ac1cc1 | Source: Benchmarking graph neural networks.pdf | Content: 18.8 Summary . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 419
# Part IV Broad and Emerging Applications with Graph Neural Networks
# 19 Graph Neural Netw...
# ID: b06b4d15-c990-41b9-a1c1-14faa126837c | Source: Benchmarking graph neural networks.pdf | Content: Chapter 16
# Heterogeneous Graph Neural Networks
# Chuan Shi
# Abstract Heterogeneous graphs (HGs) also called heterogeneous information net-
# works (HINs) have become ubiquitous in real-world scenarios. Rec...
# ID: 7e871141-5d5f-4ab6-9c36-8e6dee90f239 | Source: Continuous graph neural networks.pdf | Content: 15.3.2 Types of Evolution . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 333
# 15.3.3 Prediction Problems, Interpolation, and Extrapolation . . . 334
# 15.4 Modeling Dynamic Graphs with G...
# ID: 8727476d-28dd-4b12-99a1-f57fd9fe41d1 | Source: Continuous graph neural networks.pdf | Content: 18.8 Summary . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 419
# Part IV Broad and Emerging Applications with Graph Neural Networks
# 19 Graph Neural Netw...
# ID: 65d4b325-272b-4b00-ba6c-c903e61cdcff | Source: Continuous graph neural networks.pdf | Content: Chapter 16
# Heterogeneous Graph Neural Networks
# Chuan Shi
# Abstract Heterogeneous graphs (HGs) also called heterogeneous information net-
# works (HINs) have become ubiquitous in real-world scenarios. Rec...
# ID: fcc1d77a-8290-4dc9-85da-31490dc75ead | Source: Graph neural networks in IoT_ A survey.pdf | Content: Natural Language Processing: A Survey. arXiv preprint arXiv:2106.06090 (2021).
# [282] Lingfei Wu, Peng Cui, Jian Pei, Liang Zhao, and Le Song. 2022. Graph Neural Networks. In Graph Neural Networks: Fou...
# ID: acf1b646-ecc9-4299-825b-21634ae4854a | Source: Graph neural networks.pdf | Content: 15.3.2 Types of Evolution . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 333
# 15.3.3 Prediction Problems, Interpolation, and Extrapolation . . . 334
# 15.4 Modeling Dynamic Graphs with G...
# ID: dad3ec73-2cde-4617-9502-2ab3452d8011 | Source: Graph neural networks.pdf | Content: 18.8 Summary . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 419
# Part IV Broad and Emerging Applications with Graph Neural Networks
# 19 Graph Neural Netw...
# ID: ec9eac29-562b-41f0-ab9b-00f780a0f94d | Source: Graph neural networks.pdf | Content: Chapter 16
# Heterogeneous Graph Neural Networks
# Chuan Shi
# Abstract Heterogeneous graphs (HGs) also called heterogeneous information net-
# works (HINs) have become ubiquitous in real-world scenarios. Rec...
# ID: a9d5ab23-c5a3-433a-8c9d-8afabdc41e4b | Source: Benchmarking graph neural networks.pdf | Content: 9.4.1 Overcoming limitations . . . . . . . . . . . . . . . . . . . . . . . . . . . . 190
# 9.5 Applications of graph neural networks for graph classification . . . . 191
# 9.6 Benchmark Datasets . . . . ....
# ID: b06d301f-e4ec-422e-a7ba-77f4c8abc90a | Source: Continuous graph neural networks.pdf | Content: 9.4.1 Overcoming limitations . . . . . . . . . . . . . . . . . . . . . . . . . . . . 190
# 9.5 Applications of graph neural networks for graph classification . . . . 191
# 9.6 Benchmark Datasets . . . . ....
# ID: 59b87ebf-825d-4032-b564-a48ebac60c16 | Source: Graph neural networks.pdf | Content: 9.4.1 Overcoming limitations . . . . . . . . . . . . . . . . . . . . . . . . . . . . 190
# 9.5 Applications of graph neural networks for graph classification . . . . 191
# 9.6 Benchmark Datasets . . . . ....
# ID: ef39e229-5a40-4341-8001-10504700929b | Source: Benchmarking graph neural networks.pdf | Content: 4
# Graph Neural Networks for Node Classification 43
# 4.2.1 General Framework of Graph Neural Networks
# The essential idea of graph neural networks is to iteratively update the node repre-
# sentations by c...
# ID: c6988aa2-d3f9-46bd-b570-4d93adcb06a0 | Source: Benchmarking graph neural networks.pdf | Content: References 679
# You J, Ying R, Leskovec J (2019) Position-aware graph neural networks. In: Inter-
# national Conference on Machine Learning, PMLR, pp 7134–7143
# You J, Ying Z, Leskovec J (2020a) Design sp...
# ID: 1f9fcb01-c27c-4c46-8199-de4468fca072 | Source: Continuous graph neural networks.pdf | Content: 4
# Graph Neural Networks for Node Classification 43
# 4.2.1 General Framework of Graph Neural Networks
# The essential idea of graph neural networks is to iteratively update the node repre-
# sentations by c...
# ID: 42332caf-99f9-4c3a-aa50-5b5fba81d712 | Source: Continuous graph neural networks.pdf | Content: References 679
# You J, Ying R, Leskovec J (2019) Position-aware graph neural networks. In: Inter-
# national Conference on Machine Learning, PMLR, pp 7134–7143
# You J, Ying Z, Leskovec J (2020a) Design sp...
# ID: c8aae633-5c1f-4410-b037-35497d60a93a | Source: Graph neural networks.pdf | Content: 4
# Graph Neural Networks for Node Classification 43
# 4.2.1 General Framework of Graph Neural Networks
# The essential idea of graph neural networks is to iteratively update the node repre-
# sentations by c...
# ID: 24c66560-d5f5-4112-b160-0a714e84b8af | Source: Benchmarking graph neural networks.pdf | Content: Graph Neural Networks: Foundations,
# Frontiers, and Applications...
# ID: 4f4ec784-9843-4333-8be5-14a18eedebc4 | Source: Benchmarking graph neural networks.pdf | Content: Part II
# Foundations of Graph Neural Networks...
# ID: e9d32180-02b6-481f-b972-c208d8a881af | Source: Benchmarking graph neural networks.pdf | Content: Part III
# Frontiers of Graph Neural Networks...
# ID: f4e5daad-71e2-4337-b686-03e78363d892 | Source: Continuous graph neural networks.pdf | Content: Graph Neural Networks: Foundations,
# Frontiers, and Applications...
# ID: 1e9dc5ce-2fa8-4d66-8e45-ed3efd660294 | Source: Continuous graph neural networks.pdf | Content: Part II
# Foundations of Graph Neural Networks...
# ID: 11a9aecc-a038-47da-a0f5-fb5ed500834a | Source: Continuous graph neural networks.pdf | Content: Part III
# Frontiers of Graph Neural Networks...
# ID: 026683bb-5d25-42bb-a93f-81d20ab201d7 | Source: Graph neural networks.pdf | Content: Graph Neural Networks: Foundations,
# Frontiers, and Applications...
# ID: e738a85d-665e-4b14-b15f-7f20bc1752b0 | Source: Graph neural networks.pdf | Content: Part II
# Foundations of Graph Neural Networks...
# ID: 0e4e4235-a56f-41ba-9ef8-79a52e86a522 | Source: Graph neural networks.pdf | Content: Part III
# Frontiers of Graph Neural Networks...
# ID: 102da029-cede-47b5-a2a5-2ffbdccb2dc7 | Source: Benchmarking graph neural networks.pdf | Content: 14
# Graph Neural Networks: Graph Structure Learning 299
# 14.2 Traditional Graph Structure Learning
# Graph structure learning has been widely studied from different perspectives in the
# literature of tradi...
# ID: 7d0991cc-d03b-4cb8-b106-5466946756fb | Source: Continuous graph neural networks.pdf | Content: 14
# Graph Neural Networks: Graph Structure Learning 299
# 14.2 Traditional Graph Structure Learning
# Graph structure learning has been widely studied from different perspectives in the
# literature of tradi...
# ID: 9c6779b0-a87c-4568-8901-080816ef31b5 | Source: Graph neural networks.pdf | Content: 14
# Graph Neural Networks: Graph Structure Learning 299
# 14.2 Traditional Graph Structure Learning
# Graph structure learning has been widely studied from different perspectives in the
# literature of tradi...
# ID: d24b5e2c-21b9-4d53-a95b-8eda8976d9fd | Source: Benchmarking graph neural networks.pdf | Content: preprint arXiv:200304078
# Sato R, Yamada M, Kashima H (2021) Random features strengthen graph neural
# networks. In: Proceedings of the 2021 SIAM International Conference on Data
# Mining (SDM), SIAM, pp 3...
# ID: db457c06-f663-4152-aae6-9516c0c4a46b | Source: Benchmarking graph neural networks.pdf | Content: Zhou K, Song Q, Huang X, Hu X (2019a) Auto-gnn: Neural architecture search of
# graph neural networks. arXiv preprint arXiv:190903184
# Zhou K, Dong Y , Wang K, Lee WS, Hooi B, Xu H, Feng J (2020c) Unders...
# ID: 42d7582f-c31a-4860-9f98-25c14f5a07f3 | Source: Continuous graph neural networks.pdf | Content: preprint arXiv:200304078
# Sato R, Yamada M, Kashima H (2021) Random features strengthen graph neural
# networks. In: Proceedings of the 2021 SIAM International Conference on Data
# Mining (SDM), SIAM, pp 3...
# ID: 574ec8a3-6151-4210-9638-a40d5617cd24 | Source: Continuous graph neural networks.pdf | Content: Zhou K, Song Q, Huang X, Hu X (2019a) Auto-gnn: Neural architecture search of
# graph neural networks. arXiv preprint arXiv:190903184
# Zhou K, Dong Y , Wang K, Lee WS, Hooi B, Xu H, Feng J (2020c) Unders...
# ID: cf6e8d35-8895-4c02-b800-db5adea8ed10 | Source: Benchmarking graph neural networks.pdf | Content: 8 Graph Neural Networks: Adversarial Robustness . . . . . . . . . . . . . . . .149
# Stephan G¨unnemann
# 8.1 Motivation . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . ....
# ID: d78e940d-3f5c-4771-949c-9819d5aeafa3 | Source: Benchmarking graph neural networks.pdf | Content: 17.4 Future Directions . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 387
# 18 Graph Neural Networks: Self-supervised Learning . . . . . . . . . . . . . . .391
# Yu Wang...
# ID: f13634c3-18fd-4154-b1ba-0c7c65cef57e | Source: Benchmarking graph neural networks.pdf | Content: 20.5.1 Visual Caption . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 457
# 20.5.2 Visual Question Answering . . . . . . . . . . . . . . . . . . . . . . . . . 458
# 20.5.3 Cross-Me...
# ID: 3f01ce75-7cf2-4826-aa86-f0f1e531783a | Source: Benchmarking graph neural networks.pdf | Content: Contents xxvii
# 20.6.2 Broader Area
# of Graph Neural Networks on Computer
# Vision . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 461
# 20.7 Summary . . . . . . . . . ...
# ID: 0a7f8915-e2ca-46da-9df2-d4b31744e9cd | Source: Benchmarking graph neural networks.pdf | Content: 26.6 Future Directions . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 577
# 27 Graph Neural Networks in Urban Intelligence . . . . . . . . . . . . . . . . . . .579
# Yan...
# ID: 78281a13-bb5e-4e24-b7c8-417f388b6759 | Source: Continuous graph neural networks.pdf | Content: 8 Graph Neural Networks: Adversarial Robustness . . . . . . . . . . . . . . . .149
# Stephan G¨unnemann
# 8.1 Motivation . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . ....
# ID: 28f6f433-84eb-45e8-ba39-a52961e414cb | Source: Continuous graph neural networks.pdf | Content: 17.4 Future Directions . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 387
# 18 Graph Neural Networks: Self-supervised Learning . . . . . . . . . . . . . . .391
# Yu Wang...
# ID: 632eb0ea-6567-4d4d-93d4-31e44d8281aa | Source: Continuous graph neural networks.pdf | Content: 20.5.1 Visual Caption . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 457
# 20.5.2 Visual Question Answering . . . . . . . . . . . . . . . . . . . . . . . . . 458
# 20.5.3 Cross-Me...
# ID: eaf119b7-112a-46b7-8a40-c3261dd9ec26 | Source: Continuous graph neural networks.pdf | Content: Contents xxvii
# 20.6.2 Broader Area
# of Graph Neural Networks on Computer
# Vision . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 461
# 20.7 Summary . . . . . . . . . ...
# ID: c7208db9-b599-41ac-b75c-ce9c17b3358c | Source: Continuous graph neural networks.pdf | Content: 26.6 Future Directions . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 577
# 27 Graph Neural Networks in Urban Intelligence . . . . . . . . . . . . . . . . . . .579
# Yan...
# ID: 5425c345-fc93-46b7-9ddf-50340f908920 | Source: Graph neural networks.pdf | Content: 8 Graph Neural Networks: Adversarial Robustness . . . . . . . . . . . . . . . .149
# Stephan G¨unnemann
# 8.1 Motivation . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . ....
# ID: 79ea5b03-e743-4345-ae42-1c2167d6e5db | Source: Graph neural networks.pdf | Content: 17.4 Future Directions . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 387
# 18 Graph Neural Networks: Self-supervised Learning . . . . . . . . . . . . . . .391
# Yu Wang...
# ID: cedaea70-b448-4aec-805a-7a126790b6ba | Source: Graph neural networks.pdf | Content: 20.5.1 Visual Caption . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 457
# 20.5.2 Visual Question Answering . . . . . . . . . . . . . . . . . . . . . . . . . 458
# 20.5.3 Cross-Me...
# ID: 0a485671-dd06-4689-a547-d7f8c2671ffa | Source: Graph neural networks.pdf | Content: Contents xxvii
# 20.6.2 Broader Area
# of Graph Neural Networks on Computer
# Vision . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 461
# 20.7 Summary . . . . . . . . . ...
# ID: 527a77f1-1edf-4a27-8442-6b23d466b42c | Source: Graph neural networks.pdf | Content: 26.6 Future Directions . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 577
# 27 Graph Neural Networks in Urban Intelligence . . . . . . . . . . . . . . . . . . .579
# Yan...
# ID: 9fc152e5-2b5a-4f6b-a99d-f990119553c4 | Source: Benchmarking graph neural networks.pdf | Content: Chapter 6
# Graph Neural Networks: Scalability
# Hehuan Ma, Yu Rong, and Junzhou Huang
# Abstract Over the past decade, Graph Neural Networks have achieved remarkable
# success in modeling complex graph data....
# ID: 0a83fce5-62f0-4b34-b969-e3040eb7aa66 | Source: Continuous graph neural networks.pdf | Content: Chapter 6
# Graph Neural Networks: Scalability
# Hehuan Ma, Yu Rong, and Junzhou Huang
# Abstract Over the past decade, Graph Neural Networks have achieved remarkable
# success in modeling complex graph data....
# ID: ca7ca033-de44-4721-a322-bd2979210183 | Source: Graph neural networks.pdf | Content: Chapter 6
# Graph Neural Networks: Scalability
# Hehuan Ma, Yu Rong, and Junzhou Huang
# Abstract Over the past decade, Graph Neural Networks have achieved remarkable
# success in modeling complex graph data....
# ID: 54788f75-79fc-455f-8036-36c4d1474ac8 | Source: Benchmarking graph neural networks.pdf | Content: (2017a). It is occasionally used as a synonym for graph neural network, i.e.,
# referring to any neural network working on the graph data, in some literature.
# • Message-Passing: Message-passing is a fra...
# ID: 8ae1ee87-1661-483e-9bd0-17442728b057 | Source: Continuous graph neural networks.pdf | Content: (2017a). It is occasionally used as a synonym for graph neural network, i.e.,
# referring to any neural network working on the graph data, in some literature.
# • Message-Passing: Message-passing is a fra...
# ID: 64851b25-4eaa-4049-b16e-537cf2d0fd9b | Source: Graph neural networks.pdf | Content: (2017a). It is occasionally used as a synonym for graph neural network, i.e.,
# referring to any neural network working on the graph data, in some literature.
# • Message-Passing: Message-passing is a fra...
# ID: c175d954-06f2-4dde-a8e8-1dd55ac87048 | Source: Benchmarking graph neural networks.pdf | Content: Part IV
# Broad and Emerging Applications with
# Graph Neural Networks...
# ID: 41829e31-53ad-4fd5-b5ab-90ccbc9d5c99 | Source: Continuous graph neural networks.pdf | Content: Part IV
# Broad and Emerging Applications with
# Graph Neural Networks...
# ID: 6562092e-05bd-4fc8-afef-4a911f980abf | Source: Graph neural networks.pdf | Content: Part IV
# Broad and Emerging Applications with
# Graph Neural Networks...
# ID: 635ae34a-41c6-4418-80a1-0209f422bfc5 | Source: Benchmarking graph neural networks.pdf | Content: 578 Shen Wang, Philip S. Yu
# Editor’s Notes: Graph neural networks for anomaly detection can be con-
# sidered as a downstream task of graph representation learning, where the
# long-term challenges in ano...
# ID: 1c4f6203-3924-452a-ab52-329051127382 | Source: Continuous graph neural networks.pdf | Content: 578 Shen Wang, Philip S. Yu
# Editor’s Notes: Graph neural networks for anomaly detection can be con-
# sidered as a downstream task of graph representation learning, where the
# long-term challenges in ano...
# ID: d7aaa44f-017d-4946-8a3a-3e79e30c241c | Source: Benchmarking graph neural networks.pdf | Content: 27.1.3 Representing urban systems as graphs . . . . . . . . . . . . . . . . 584
# 27.1.4 Case Study 1: Graph Neural Networksin urban
# configuration and transportation . . . . . . . . . . . . . . . . . . ...
# ID: 4f4c382c-7cdc-4520-98c5-1d0ca475c2d6 | Source: Continuous graph neural networks.pdf | Content: 27.1.3 Representing urban systems as graphs . . . . . . . . . . . . . . . . 584
# 27.1.4 Case Study 1: Graph Neural Networksin urban
# configuration and transportation . . . . . . . . . . . . . . . . . . ...
# ID: 850280ff-ac0b-40fd-b435-1e0eb75ac415 | Source: Evaluating explainability for graph neural networks.pdf | Content: 9. Lucic, A., Ter Hoeve, M. A., Tolomei, G., De Rijke, M. & Silvestri, F . Cf-gnnexplainer: Counterfactual explanations for graph neural
# networks. In AISTATS (PMLR, 2022).
#  10. Luo, D. et al. Paramet...
# ID: 5c1f2b55-fd0b-47c3-a996-0dd232fcdefd | Source: Graph neural networks.pdf | Content: 27.1.3 Representing urban systems as graphs . . . . . . . . . . . . . . . . 584
# 27.1.4 Case Study 1: Graph Neural Networksin urban
# configuration and transportation . . . . . . . . . . . . . . . . . . ...
# ID: eebd1962-ebc0-4c0b-af56-ad785d050932 | Source: Benchmarking graph neural networks.pdf | Content: Chapter 5
# The Expressive Power of Graph Neural
# Networks
# Pan Li and Jure Leskovec
# Abstract The success of neural networks is based on their strong expressive power
# that allows them to approximate compl...
# ID: d8a7927b-fcd4-4ba7-8ef8-a38f430d0e1f | Source: Continuous graph neural networks.pdf | Content: Chapter 5
# The Expressive Power of Graph Neural
# Networks
# Pan Li and Jure Leskovec
# Abstract The success of neural networks is based on their strong expressive power
# that allows them to approximate compl...
# ID: 98da68f2-c572-418f-8560-d81b25843133 | Source: Graph neural networks.pdf | Content: Chapter 5
# The Expressive Power of Graph Neural
# Networks
# Pan Li and Jure Leskovec
# Abstract The success of neural networks is based on their strong expressive power
# that allows them to approximate compl...
# ID: df2defe0-4305-41cb-a959-3e0caed2d21f | Source: Graph neural network approaches for drug-target interactions.pdf | Content: neural networks (CNNs) and recurrent neural networks
# (RNNs) can automatically extract features from texts
# (protein sequences and SMILES) and images (3D
# grids) [7,8]. However, all these features are Eu...
# ID: a23ede86-dd0a-45b9-9673-a432e46310e4 | Source: Graph neural networks for materials science and chemistry.pdf | Content: strong ties to theﬁeld of geometric deep learning17–19. Aside from research on social and citation
# networks as well as knowledge graphs, chemistry has been one of the main drivers in the
# development o...
# ID: c108eb7e-6443-4836-888e-787d29a73d69 | Source: Benchmarking graph neural networks.pdf | Content: GCN. In: ACM International Conference on Information & Knowledge Manage-
# ment, DOI 10.1145/3340531.3411983
# Zhang M, Chen Y (2018a) Link prediction based on graph neural networks. In:
# Advances in Neura...
# ID: 94c3dd6b-41a4-40cd-be40-16976ae05cb7 | Source: Continuous graph neural networks.pdf | Content: GCN. In: ACM International Conference on Information & Knowledge Manage-
# ment, DOI 10.1145/3340531.3411983
# Zhang M, Chen Y (2018a) Link prediction based on graph neural networks. In:
# Advances in Neura...
# ID: 691dad9e-e822-4b46-b643-8afe02b6d8fe | Source: Benchmarking graph neural networks.pdf | Content: Chapter 10
# Graph Neural Networks: Link Prediction
# Muhan Zhang
# Abstract Link prediction is an important application of graph neural networks. By
# predicting missing or future links between pairs of node...
# ID: 2027fa0e-4dde-4b7f-a9d5-ea37f1caa275 | Source: Continuous graph neural networks.pdf | Content: Chapter 10
# Graph Neural Networks: Link Prediction
# Muhan Zhang
# Abstract Link prediction is an important application of graph neural networks. By
# predicting missing or future links between pairs of node...
# ID: e73d5dfb-9d6f-4609-8257-0987edd1e543 | Source: Graph neural networks.pdf | Content: Chapter 10
# Graph Neural Networks: Link Prediction
# Muhan Zhang
# Abstract Link prediction is an important application of graph neural networks. By
# predicting missing or future links between pairs of node...
# ID: 0c294837-b111-4bd6-9ef0-456dca51372d | Source: Benchmarking graph neural networks.pdf | Content: 4
# Graph Neural Networks for Node Classification 49
# the discrete dynamics of node representations with GNNs. Xhonneux et al (2020)
# proposed the continuous graph neural networks (CGNNs), which generaliz...
# ID: 4cc1570f-41e9-497c-aa7f-ea5b788d0ff1 | Source: Benchmarking graph neural networks.pdf | Content: 4
# Graph Neural Networks for Node Classification 51
# the natural solution of the system while X is the information provided to the system
# to drive the system into the desired state.
# Discussion. The prop...
# ID: 61bb47a0-6b8d-4449-bbeb-775c134e39b6 | Source: Benchmarking graph neural networks.pdf | Content: 4 Graph Neural Networks for Node Classification 61
# where s is a hyperparameter determining C. At the end, we have
# TPSD( ˆH) =2N||ˆH||2
# F = 2N ∑
# i
# ||s ·
# ˜Hc
# i√
# 1
# N ∑N
# i=1 ||˜Hc
# i ||2
# 2
# ||2
# 2 = 2N2s2 (4...
# ID: 119cd272-9395-4684-a957-47508eef61e6 | Source: Benchmarking graph neural networks.pdf | Content: problem of training deep graph neural networks—over-smoothing, and introduce a
# method to tackle it. In the future, promising directions on graph neural networks in-
# clude theoretical analysis for unde...
# ID: efb7ac53-8e6f-4e43-9b9d-535bee3e1580 | Source: Continuous graph neural networks.pdf | Content: 4
# Graph Neural Networks for Node Classification 49
# the discrete dynamics of node representations with GNNs. Xhonneux et al (2020)
# proposed the continuous graph neural networks (CGNNs), which generaliz...
# ID: 0dca2f7f-9ef0-48a9-97c1-0eba01929efb | Source: Continuous graph neural networks.pdf | Content: 4
# Graph Neural Networks for Node Classification 51
# the natural solution of the system while X is the information provided to the system
# to drive the system into the desired state.
# Discussion. The prop...
# ID: 5a519bca-7980-47da-ac9f-28918c00efb3 | Source: Continuous graph neural networks.pdf | Content: 4 Graph Neural Networks for Node Classification 61
# where s is a hyperparameter determining C. At the end, we have
# TPSD( ˆH) =2N||ˆH||2
# F = 2N ∑
# i
# ||s ·
# ˜Hc
# i√
# 1
# N ∑N
# i=1 ||˜Hc
# i ||2
# 2
# ||2
# 2 = 2N2s2 (4...
# ID: 185355cb-8646-426d-9e6c-bae7f74503be | Source: Continuous graph neural networks.pdf | Content: problem of training deep graph neural networks—over-smoothing, and introduce a
# method to tackle it. In the future, promising directions on graph neural networks in-
# clude theoretical analysis for unde...
# ID: c6d424a6-d157-4191-8980-034ade2b1046 | Source: Evaluating explainability for graph neural networks.pdf | Content: In CVPR (2019).
#  12. Schlichtkrull, M. S., De Cao, N. & Titov, I. Interpreting graph neural networks for nlp with differentiable edge masking. In ICLR
# (2021).
#  13. Vu, M. N. & Thai, M. T. PGM-Explai...
# ID: 3c210bdd-5f33-48ea-994b-d87fe36d1fc4 | Source: Graph neural network approaches for drug-target interactions.pdf | Content: graph neural networks for Covid-19 drug-repurposing. arXiv
# preprint :.10261 2020. https://arxiv.org/abs/2007.10261; 2020.
# 84. Siddhant D, Prabhakar CS:Dr-COVID: graph neural networks
# for SARS-CoV-2 dr...
# ID: d1caddbc-9fcd-464d-ab2d-f31b8190e491 | Source: Graph neural networks for graphs with heterophily_ A survey.pdf | Content: Learning Representations, 2018.
# [10] K. Xu, W. Hu, J. Leskovec, and S. Jegelka, “How powerful are graph
# neural networks?” in International Conference on Learning Represen-
# tations, 2019.
# [11] Z. Wu, S...
# ID: 9b5f1363-5958-428a-8673-4112da7f23c6 | Source: Graph neural networks.pdf | Content: 4
# Graph Neural Networks for Node Classification 49
# the discrete dynamics of node representations with GNNs. Xhonneux et al (2020)
# proposed the continuous graph neural networks (CGNNs), which generaliz...
# ID: 0ae3c87a-2ed0-409d-8020-79af8562237d | Source: Graph neural networks.pdf | Content: 4
# Graph Neural Networks for Node Classification 51
# the natural solution of the system while X is the information provided to the system
# to drive the system into the desired state.
# Discussion. The prop...
# ID: bd79406e-6eb2-4a56-9da1-39e8e3f272d3 | Source: Graph neural networks.pdf | Content: 4 Graph Neural Networks for Node Classification 61
# where s is a hyperparameter determining C. At the end, we have
# TPSD( ˆH) =2N||ˆH||2
# F = 2N ∑
# i
# ||s ·
# ˜Hc
# i√
# 1
# N ∑N
# i=1 ||˜Hc
# i ||2
# 2
# ||2
# 2 = 2N2s2 (4...
# ID: ccac4c30-e6b2-423c-8c32-e951bbb53b83 | Source: Graph neural networks.pdf | Content: problem of training deep graph neural networks—over-smoothing, and introduce a
# method to tackle it. In the future, promising directions on graph neural networks in-
# clude theoretical analysis for unde...
# ID: 1a8f3869-b954-451c-b087-fa5f5f47abdc | Source: Graph neural networks in IoT_ A survey.pdf | Content: devices including smart wearables, cameras, smartwatches, and autonomous vehicles can accurately measure and perceive
# their surrounding environment. Continuous sensing generates massive amounts of dat...
# ID: 61da33df-99e5-466e-9a29-8729a10d0db2 | Source: A survey on oversmoothing in graph neural networks.pdf | Content: Graph neural networks: a review of methods and applications. arXiv:1812.08434v4, 2019.
# Kaixiong Zhou, Xiao Huang, Yuening Li, Daochen Zha, Rui Chen, and Xia Hu. Towards deeper graph neural networks
# wi...
# ID: c0055b33-6546-4cc4-b111-28ac4726b73e | Source: Graph neural networks for materials science and chemistry.pdf | Content: 124. Wu, Z. et al. A comprehensive survey on graph neural networks.IEEE Trans.
# Neural Netw. Learn. Syst.32,4 –24 (2021).
# 125. Yuan, Y., Wang, W. & Pang, W. A systematic comparison study on
# hyperparame...
# ID: 93560bb5-c233-4476-a160-86861144ff71 | Source: Evaluating explainability for graph neural networks.pdf | Content: 30. Sundararajan, M., Taly, A. & Y an, Q. Axiomatic attribution for deep networks. In ICML (2017).
#  31. Yuan, H., Yu, H., Wang, J., Li, K. & Ji, S. On explainability of graph neural networks via subgr...
# ID: a26b1018-4096-4bb3-8f2e-01338580333d | Source: Graph neural networks for materials science and chemistry.pdf | Content: 17. Sperduti, A. & Starita, A. Supervised neural networks for the classiﬁcation of
# structures. IEEE Trans. Neural Netw.8, 714–735 (1997).
# 18. Gori, M., Monfardini, G. & Scarselli, F. A new model for l...
# ID: 3eec8432-895e-49c1-ae60-9394b0679d57 | Source: Benchmarking graph neural networks.pdf | Content: Chapter 11
# Graph Neural Networks: Graph Generation
# Renjie Liao
# Abstract In this chapter, we first review a few classic probabilistic models for graph
# generation including the Erd ˝os–R´enyi model and ...
# ID: 0db2d11f-dab3-41ec-a9fd-741816f88713 | Source: Continuous graph neural networks.pdf | Content: Chapter 11
# Graph Neural Networks: Graph Generation
# Renjie Liao
# Abstract In this chapter, we first review a few classic probabilistic models for graph
# generation including the Erd ˝os–R´enyi model and ...
# ID: e00675a6-34ff-417f-9f42-5cabd5cd97bd | Source: Graph neural networks.pdf | Content: Chapter 11
# Graph Neural Networks: Graph Generation
# Renjie Liao
# Abstract In this chapter, we first review a few classic probabilistic models for graph
# generation including the Erd ˝os–R´enyi model and ...
# ID: 2e965c9e-ffb1-46e5-b08f-dfaa8b2d3503 | Source: Benchmarking graph neural networks.pdf | Content: on graph neural networks. IEEE Transactions on Neural Networks and Learning
# Systems 32(1):4–24
# Xhonneux LP, Qu M, Tang J (2020) Continuous graph neural networks. In: Pro-
# ceedings of the International...
# ID: b7b2bf9a-02a2-446c-8ff5-3e9135b6e28b | Source: Benchmarking graph neural networks.pdf | Content: 2983711
# Xie S, Kirillov A, Girshick R, He K (2019a) Exploring randomly wired neural
# networks for image recognition. In: Proceedings of the IEEE/CVF International
# Conference on Computer Vision, pp 1284...
# ID: 1b95e082-6f51-45d3-b342-21734e4822b9 | Source: Continuous graph neural networks.pdf | Content: on graph neural networks. IEEE Transactions on Neural Networks and Learning
# Systems 32(1):4–24
# Xhonneux LP, Qu M, Tang J (2020) Continuous graph neural networks. In: Pro-
# ceedings of the International...
# ID: d4728581-bbe5-476b-a694-bd0386e6fee9 | Source: Continuous graph neural networks.pdf | Content: 2983711
# Xie S, Kirillov A, Girshick R, He K (2019a) Exploring randomly wired neural
# networks for image recognition. In: Proceedings of the IEEE/CVF International
# Conference on Computer Vision, pp 1284...
# ID: 1a1d3420-5d3a-47c9-b7f3-f182657c6752 | Source: Graph neural networks for graphs with heterophily_ A survey.pdf | Content: classification,” IEEE Transactions on Neural Networks and Learning
# Systems, 2022, doi: 10.1109/TNNLS.2022.3161453.
# [60] C. Liu, X. Ma, Y . Zhan, L. Ding, D. Tao, B. Du, W. Hu, and D. P.
# Mandic, “Compr...
# ID: d98b7caf-ebbb-43cb-baeb-575e9d00f945 | Source: Graph neural networks for materials science and chemistry.pdf | Content: neural networks or Gaussian Processes. Geometric information
# can also be used for node or edge representations in graph neural
# networks. Graph networks have been adopting distances 61,
# bond72 and even...
# ID: 24c33050-bb1a-4a8a-ae37-6d44b89ebe01 | Source: Graph neural networks in IoT_ A survey.pdf | Content: arXiv:2011.02260 (2020).
# [284] Yulei Wu, Hong-Ning Dai, and Haina Tang. 2021. Graph neural networks for anomaly detection in industrial internet of things. IEEE
# Internet of Things Journal (2021).
# [285...
# ID: 6b3849ae-120b-4e3f-8945-d5ab50be0ff9 | Source: Benchmarking graph neural networks.pdf | Content: Graph Neural
# Networks
# Foundations,
# Frontiers,
# and Applications
# Lingfei Wu · Peng Cui
# Jian Pei · Liang Zhao Eds....
# ID: 35a5b6e3-4943-4b11-ba7c-1d22c98a4ab2 | Source: Benchmarking graph neural networks.pdf | Content: using graph neural networks. In: International Conference on Learning Represen-
# tations...
# ID: 8aba1e97-2310-4b1e-a10a-5565641b446a | Source: Benchmarking graph neural networks.pdf | Content: Graph to sequence learning with attention-based neural networks. arXiv preprint
# arXiv:180400823...
# ID: ea3b4cce-1be1-4557-82b3-3a52752cc509 | Source: Continuous graph neural networks.pdf | Content: Graph Neural
# Networks
# Foundations,
# Frontiers,
# and Applications
# Lingfei Wu · Peng Cui
# Jian Pei · Liang Zhao Eds....
# ID: dcdb07a2-b2f7-488c-9946-33bc357c5ffd | Source: Continuous graph neural networks.pdf | Content: using graph neural networks. In: International Conference on Learning Represen-
# tations...
# ID: dba4a35d-9e86-438a-af8b-e747eecf1853 | Source: Continuous graph neural networks.pdf | Content: Graph to sequence learning with attention-based neural networks. arXiv preprint
# arXiv:180400823...
# ID: 7b2d9ac6-6110-4bff-8a3d-8f10d823f136 | Source: Graph neural networks.pdf | Content: Graph Neural
# Networks
# Foundations,
# Frontiers,
# and Applications
# Lingfei Wu · Peng Cui
# Jian Pei · Liang Zhao Eds....
# ID: c979760f-6f42-4a89-beeb-06840dbccbf0 | Source: Benchmarking graph neural networks.pdf | Content: Chapter 17
# Graph Neural Networks: AutoML
# Kaixiong Zhou, Zirui Liu, Keyu Duan and Xia Hu
# Abstract Graph neural networks (GNNs) are efficient deep learning tools to analyze
# networked data. Being widely ...
# ID: 89a816b6-6616-4b8e-a80b-e98e8fb396e4 | Source: Continuous graph neural networks.pdf | Content: Chapter 17
# Graph Neural Networks: AutoML
# Kaixiong Zhou, Zirui Liu, Keyu Duan and Xia Hu
# Abstract Graph neural networks (GNNs) are efficient deep learning tools to analyze
# networked data. Being widely ...
# ID: 8596126c-b91c-4859-95c3-3c635587f0ce | Source: Graph neural networks.pdf | Content: Chapter 17
# Graph Neural Networks: AutoML
# Kaixiong Zhou, Zirui Liu, Keyu Duan and Xia Hu
# Abstract Graph neural networks (GNNs) are efficient deep learning tools to analyze
# networked data. Being widely ...
# ID: 3c962b39-efb8-43a5-aa14-b9f1005e4be1 | Source: Benchmarking graph neural networks.pdf | Content: tion. Afterwards, we will introduce a few representative architectures of graph neu-
# ral networks for node classification. We will further point out the main difficulty—
# the oversmoothing problem—of t...
# ID: e0714017-1a29-41d7-a91a-708aacae12b9 | Source: Continuous graph neural networks.pdf | Content: tion. Afterwards, we will introduce a few representative architectures of graph neu-
# ral networks for node classification. We will further point out the main difficulty—
# the oversmoothing problem—of t...
# ID: cdf911a4-9b68-416b-bab1-96a4f9835bb5 | Source: Graph neural networks.pdf | Content: tion. Afterwards, we will introduce a few representative architectures of graph neu-
# ral networks for node classification. We will further point out the main difficulty—
# the oversmoothing problem—of t...
# ID: 5400c628-e8a7-485d-8d77-68d8b3bf4479 | Source: A survey on oversmoothing in graph neural networks.pdf | Content: K Oono and T Suzuki. Graph neural networks exponentially lose expressive power for node classiﬁcation. In ICLR,
# 2020.
# Hongbin Pei, Bingzhe Wei, Kevin Chen-Chuan Chang, Yu Lei, and Bo Yang. Geom-gcn: G...
# ID: 88388ec7-5bdb-498e-b735-dd5e6ef75178 | Source: Benchmarking graph neural networks.pdf | Content: xxii Contents
# 8.4 Impro
# ving Robustness of Graph Neural Networks . . . . . . . . . . . . . . 165
# 8.4.1 Improving the Graph . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 166
# 8.4.2 Impro...
# ID: ef3c1a46-a6b1-4999-bdc4-12e903291a17 | Source: Benchmarking graph neural networks.pdf | Content: 18.8 Summary
# In this chapter, we provided a systemic, categorical and comprehensive overview on
# the recent works leveraging self-supervised learning in graph neural networks. De-
# spite recent successe...
# ID: dedf11c1-e903-4d58-8cff-32c501f5fc89 | Source: Continuous graph neural networks.pdf | Content: xxii Contents
# 8.4 Impro
# ving Robustness of Graph Neural Networks . . . . . . . . . . . . . . 165
# 8.4.1 Improving the Graph . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 166
# 8.4.2 Impro...
# ID: 4d465d58-d1dc-4274-b261-cb1be61e50b1 | Source: Continuous graph neural networks.pdf | Content: 18.8 Summary
# In this chapter, we provided a systemic, categorical and comprehensive overview on
# the recent works leveraging self-supervised learning in graph neural networks. De-
# spite recent successe...
# ID: ad5ddec5-0396-48f9-902d-ed6890cd8ac4 | Source: Graph neural networks in IoT_ A survey.pdf | Content: nodes can be generated to encode topological and temporal dynamics within human states. Dynamic GNNs
# combine graph convolutional neural networks (GCNNs) and recurrent neural networks (RNNs) to capture...
# ID: f8096246-6cb3-475f-9336-bf9c9f28479a | Source: Graph neural networks.pdf | Content: xxii Contents
# 8.4 Impro
# ving Robustness of Graph Neural Networks . . . . . . . . . . . . . . 165
# 8.4.1 Improving the Graph . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 166
# 8.4.2 Impro...
# ID: 99107058-951f-4765-a9b6-0882834b1185 | Source: Graph neural networks.pdf | Content: 18.8 Summary
# In this chapter, we provided a systemic, categorical and comprehensive overview on
# the recent works leveraging self-supervised learning in graph neural networks. De-
# spite recent successe...
# ID: 84932d2b-194a-478f-98bb-a213b0409ec3 | Source: Benchmarking graph neural networks.pdf | Content: Chapter 4
# Graph Neural Networks for Node Classification
# Jian Tang and Renjie Liao
# Abstract Graph Neural Networks are neural architectures specifically designed for
# graph-structured data, which have be...
# ID: f2fd6ae3-1dd0-4774-b89f-a641f474b054 | Source: Benchmarking graph neural networks.pdf | Content: Here we only introduce a few representative architectures of graph neural net-
# works for node classification. There are also many other well-known architectures
# including gated graph neural networks (...
# ID: 31502d4c-79ae-4f71-97c1-1ba0711b5fa8 | Source: Benchmarking graph neural networks.pdf | Content: mances. There seems no such a universally good corruption function. One needs to
# do trial–and-error to obtain a proper one depending on the task/dataset.
# 4.4 Over-smoothing Problem
# Training deep graph...
# ID: befdc243-57ca-4571-94b1-3ed00b003ee8 | Source: Benchmarking graph neural networks.pdf | Content: 20 Graph Neural Networks in Computer Vision 455
# ject proposals as graph nodes and learn the relations between them. In this section,
# ...
# graph is obtained via the tree decomposition as shown in the top-right. A...
# ID: 1098d28f-0e5a-4220-95ae-b4fff063a146 | Source: Continuous graph neural networks.pdf | Content: 12
# Graph Neural Networks: Graph Transformation 253
# 12.2 Node-level Transformation
# 12.2.1 Definition of Node-level Transformation
# Node-level transformation aims to generate or predict the node attribut...
# ID: 61fb1044-c487-4366-8dca-71e2c1bf7798 | Source: Continuous graph neural networks.pdf | Content: 13
# Graph Neural Networks: Graph Matching 295
# 13.4 Summary
# In this chapter, we have introduced the general graph matching learning, whereby
# objective functions are formulated for establishing an optima...
# ID: 73adb50a-6273-4bfa-9a13-3de54b1a56bd | Source: Continuous graph neural networks.pdf | Content: 14
# Graph Neural Networks: Graph Structure Learning 311
# Structure-aware Similarity Metric Learning
# When learning implicit graph structures from data, it might be beneficial to utilize
# the intrinsic gra...
# ID: 835812cc-43d7-4bfc-af5c-b23d5863ba6a | Source: Continuous graph neural networks.pdf | Content: 14
# Graph Neural Networks: Graph Structure Learning 313
# nodes to have similar features, thus enforcing smoothness of the graph signals on
# the graph associated with A. However, solely minimizing the smo...
# ID: d105bb01-060e-4ebc-a170-ec97cb398d4f | Source: Continuous graph neural networks.pdf | Content: 14
# Graph Neural Networks: Graph Structure Learning 317
# learning procedure dynamically stops when the learned graph structure approaches
# close enough to the optimized graph (with respect to the downstr...
# ID: 00c04bb7-157a-4fed-b0bb-571b49f42141 | Source: Continuous graph neural networks.pdf | Content: 17
# Graph Neural Networks: AutoML 377
# 17.2.1 Architecture Search Space
# Considering the existing AutoGNN frameworks (Gao et al, 2020b; Zhou et al,
# 2019a), GNN model is commonly implemented based on the ...
# ID: 15323cb9-044e-4968-a9d2-84e6ec2724bd | Source: Continuous graph neural networks.pdf | Content: a graph perspective based on the different representations we have introduced. In
# recent years, many research works apply graph neural networks (Wu et al, 2021d)
# to solve NLP problems. A majority of t...
# ID: 679c19de-4a75-4cd4-a57c-151f5eb4a158 | Source: Continuous graph neural networks.pdf | Content: tasks. While multiple techniques have been developed in past decades in address-
# ing unstructured collections of multi-dimensional data, graph-structure-aware tech-
# niques have recently attracted cons...
# ID: 2757e70a-6131-438a-a139-31850f1f0880 | Source: Continuous graph neural networks.pdf | Content: e.g., urban social graph, transportation graph. These urban graph data can enable
# intelligent solutions to solve various urban challenges, such as urban facility plan-
# ning, air pollution, etc. Howeve...
# ID: 09ac54c8-84e2-4650-85b5-7d4ba658de7a | Source: Continuous graph neural networks.pdf | Content: learning for graph neural networks. arXiv preprint arXiv:210205034
# Feng B, Wang Y , Wang Z, Ding Y (2021) Uncertainty-aware Attention Graph Neu-
# ral Network for Defending Adversarial Attacks. In: AAAI...
# ID: 36e7a645-6b51-40fa-a3ac-5b707c26c6d7 | Source: Evaluating explainability for graph neural networks.pdf | Content: in various real-world areas. We include ShapeGGen and several real-world graph datasets in a graph
# explainability library, GraphXAI. In addition to synthetic and real-world graph datasets with ground...
# ID: fe7d9d58-73be-41dd-b9d8-9167194a6709 | Source: Graph neural networks for materials science and chemistry.pdf | Content: edges. Formally, a graph is a tupleG = (V, E) of a set of vertices
# v ∈ V and a set of edges ev,w = (v, w) ∈ E, which deﬁnes the
# connection between vertices. Potential tasks that can be solved
# using gr...
# ID: 6e5aa067-9561-4cc9-85ba-14e8b82539fe | Source: Graph neural networks in IoT_ A survey.pdf | Content: •Graph Convolutional Neural Networks (GCNs): GCNs define a neighborhood information aggregation
# process to update node representation, and stack multiple graph convolutional layers to generate high-le...
# ID: 0e4460c9-dc4a-4147-b54d-5904d8f1615b | Source: Graph neural networks.pdf | Content: ated with the whole graph. Typical examples of graph-level tasks include graph
# classification and graph property prediction.
# • Transductive and Inductive Learning : Transductive learning refers to tha...
# ID: 0e3995e3-5b17-42b0-b12b-963ff0e4c107 | Source: Graph neural networks.pdf | Content: it has shown great advantages over other conventional graph learning methods for
# link prediction. Regarding the learning types of link prediction, node-based methods
# (Kipf and Welling, 2016) and subgr...
# ID: 668b77f6-b42a-4c51-81ea-544faf88d4fd | Source: Graph neural networks.pdf | Content: Xu et al, 2018c; Li et al, 2020f).
# Graph Neural Networks: Graph Matching and Graph Structure Learning. The
# problem of graph matching is to find the correspondence between two input graphs,
# which is an...
# ID: 66be59f6-d976-4864-897f-e681752e0691 | Source: Graph neural networks.pdf | Content: 11 Graph Neural Networks: Graph Generation 235
# Fig. 11.1: Junction Tree V AEs. The junction tree corresponding to the molecule
# graph is obtained via the tree decomposition as shown in the top-right. A...
# ID: b598e13f-25d3-4dbe-8650-0afd43250ce4 | Source: Graph neural networks.pdf | Content: 12
# Graph Neural Networks: Graph Transformation 253
# 12.2 Node-level Transformation
# 12.2.1 Definition of Node-level Transformation
# Node-level transformation aims to generate or predict the node attribut...
# ID: 4be8913d-cb78-4297-9e15-4a3b2c06be4b | Source: Graph neural networks.pdf | Content: 13
# Graph Neural Networks: Graph Matching 295
# 13.4 Summary
# In this chapter, we have introduced the general graph matching learning, whereby
# objective functions are formulated for establishing an optima...
# ID: b64722a0-a5ef-4571-a610-3eb52010f452 | Source: Graph neural networks.pdf | Content: 14
# Graph Neural Networks: Graph Structure Learning 311
# Structure-aware Similarity Metric Learning
# When learning implicit graph structures from data, it might be beneficial to utilize
# the intrinsic gra...
# ID: 9c3585ff-ab98-456a-9c80-e1ba5975704f | Source: Graph neural networks.pdf | Content: 14
# Graph Neural Networks: Graph Structure Learning 313
# nodes to have similar features, thus enforcing smoothness of the graph signals on
# the graph associated with A. However, solely minimizing the smo...
# ID: ee09c7bd-7160-40cb-a9c9-f8207f2c7afa | Source: Graph neural networks.pdf | Content: 14
# Graph Neural Networks: Graph Structure Learning 317
# learning procedure dynamically stops when the learned graph structure approaches
# close enough to the optimized graph (with respect to the downstr...
# ID: 08476c12-e4f7-4ed6-89d3-721f05560c35 | Source: Graph neural networks.pdf | Content: 17
# Graph Neural Networks: AutoML 377
# 17.2.1 Architecture Search Space
# Considering the existing AutoGNN frameworks (Gao et al, 2020b; Zhou et al,
# 2019a), GNN model is commonly implemented based on the ...
# ID: 975cf00a-7207-40ba-ba8d-248cfc48936c | Source: Graph neural networks.pdf | Content: a graph perspective based on the different representations we have introduced. In
# recent years, many research works apply graph neural networks (Wu et al, 2021d)
# to solve NLP problems. A majority of t...
# ID: 7f4bf81f-798b-4512-b407-aea6ffc973cb | Source: (2)Everything is connected_ Graph neural networks.pdf | Content: it into the TPUv5.
# Monti, F., Boscaini, D., Masci, J., Rodola, E., Svoboda, J., Bronstein, M.M., 2017.
# Geometric deep learning on graphs and manifolds using mixture model cnns, in:
# Proceedings of the ...
# ID: 5f576ffa-a50d-48f6-90ac-11b6644fb4c6 | Source: (2)Graph neural networks and their current applications in bioinformatics.pdf | Content: fgene-12-690049 July 23, 2021 Time: 17:38 # 10
# Zhang et al. Graph Neural Networks in Bioinformatics
# functional similarity network and disease semantic similarity
# network, respectively, and utilized th...
# ID: cd7c4269-cbfe-49ef-8c16-53fc8ec3c113 | Source: A survey on oversmoothing in graph neural networks.pdf | Content: IEEE Trans. Neural Networks, 9(5):768–786, 1998.
# Thomas Gaudelet, Ben Day, Arian R Jamasb, Jyothish Soman, Cristian Regep, Gertrude Liu, Jeremy BR Hayter,
# Richard Vickers, Charles Roberts, Jian Tang, ...
# ID: 76bb55e4-1f33-4115-ac9d-ff988c26bde3 | Source: Benchmarking graph neural networks.pdf | Content: 5 The Expressive Power of Graph Neural Networks 65
# …
# Translation invariance
# Translation variance
# …
# …
# RNNs/CNNs share parameters
# RNNs/CNNs do not fit this case…
# …
# Features
# Targets
# Features
# Targets
# Fig....
# ID: 5fceec6a-905c-4b3c-aaa6-f3d6451723ae | Source: Benchmarking graph neural networks.pdf | Content: imated variational distribution defined in Eq. (11.6) is simple, it possesses a few
# great properties. First, the probability distribution is invariant w.r.t. the permutation
# of nodes. Mathematically, ...
# ID: 69ca129e-4063-4051-82bd-fe166b509eaa | Source: Benchmarking graph neural networks.pdf | Content: 21
# Graph Neural Networks in Natural Language Processing 465
# applied to model text. Deep learning has brought a new revolution in NLP, greatly
# improving the performance of various tasks.
# In 2018, Googl...
# ID: ccc0ed1b-a286-4892-b5c8-668d46c64d65 | Source: Benchmarking graph neural networks.pdf | Content: person 2d pose estimation using part affinity fields. IEEE transactions on pattern
# analysis and machine intelligence 43(1):172–186
# Cappart Q, Ch ´etelat D, Khalil E, Lodi A, Morris C, Veli ˇckovi´c P ...
# ID: e0112915-542d-47d2-aee0-c708fb68ad0f | Source: Benchmarking graph neural networks.pdf | Content: embedding by flexible translation. In: Proceedings of the Fifteenth International
# Conference on Principles of Knowledge Representation and Reasoning, pp 557–
# 560
# Feng W, Zhang J, Dong Y , Han Y , Luan...
# ID: a88aaf10-3b77-4f4e-ba60-935176207cb1 | Source: Benchmarking graph neural networks.pdf | Content: tional Joint Conference on Artificial Intelligence, pp 1373–1379
# Guo H, Tang R, Ye Y , Li Z, He X (2017) Deepfm: a factorization-machine based
# neural network for ctr prediction. In: Proceedings of the...
# ID: 7dd5e433-76a5-4fa0-b3c9-b4767f188621 | Source: Benchmarking graph neural networks.pdf | Content: References 631
# Kawahara J, Brown CJ, Miller SP, Booth BG, Chau V , Grunau RE, Zwicker JG,
# Hamarneh G (2017) Brainnetcnn: Convolutional neural networks for brain net-
# works; towards predicting neurodev...
# ID: c1a597cd-6a88-463d-bb16-cf3a2b69ee82 | Source: Benchmarking graph neural networks.pdf | Content: Proceedings of the Annual Meeting of the Cognitive Science Society, vol 32
# Lamb LC, Garcez A, Gori M, Prates M, Avelar P, Vardi M (2020) Graph neural
# networks meet neural-symbolic computing: A survey ...
# ID: c4139fe1-f197-4c1f-b25b-965000b29616 | Source: Benchmarking graph neural networks.pdf | Content: Li Y , Lin Y , Madhusudan M, Sharma A, Xu W, Sapatnekar SS, Harjani R, Hu J
# (2020h) A customized graph neural network model for guiding analog ic place-
# ment. In: International Conference On Computer ...
# ID: b4c04a74-1353-42ed-8d74-ed353f844735 | Source: Benchmarking graph neural networks.pdf | Content: References 647
# ternational Symposium on Foundations of Software Engineering, ACM, pp 484–
# 495
# Morris C, Kersting K, Mutzel P (2017) Glocalized Weisfeiler-Lehman kernels:
# Global-local feature maps of g...
# ID: 3410fb39-383a-466d-8d4d-cda13ec245e9 | Source: Benchmarking graph neural networks.pdf | Content: ity methods for graph convolutional neural networks. In: Proceedings of the
# IEEE/CVF Conference on Computer Vision and Pattern Recognition, pp 10,772–
# 10,781
# Pradel M, Sen K (2018) Deepbugs: A learnin...
# ID: c724556c-be65-409d-9eea-f745381c80fc | Source: Continuous graph neural networks.pdf | Content: 5 The Expressive Power of Graph Neural Networks 65
# …
# Translation invariance
# Translation variance
# …
# …
# RNNs/CNNs share parameters
# RNNs/CNNs do not fit this case…
# …
# Features
# Targets
# Features
# Targets
# Fig....
# ID: 2b76c5fb-25f9-4b11-8e1a-4df1ae3b5f89 | Source: Continuous graph neural networks.pdf | Content: imated variational distribution defined in Eq. (11.6) is simple, it possesses a few
# great properties. First, the probability distribution is invariant w.r.t. the permutation
# of nodes. Mathematically, ...
# ID: 870ed6a8-30df-49b6-a2c3-ec010bb04e69 | Source: Continuous graph neural networks.pdf | Content: 21
# Graph Neural Networks in Natural Language Processing 465
# applied to model text. Deep learning has brought a new revolution in NLP, greatly
# improving the performance of various tasks.
# In 2018, Googl...
# ID: 65e04366-927e-4fbe-b5bf-eaeff8db2843 | Source: Continuous graph neural networks.pdf | Content: person 2d pose estimation using part affinity fields. IEEE transactions on pattern
# analysis and machine intelligence 43(1):172–186
# Cappart Q, Ch ´etelat D, Khalil E, Lodi A, Morris C, Veli ˇckovi´c P ...
# ID: e5f80fd7-8380-41a2-898c-7a26f17aa826 | Source: Continuous graph neural networks.pdf | Content: embedding by flexible translation. In: Proceedings of the Fifteenth International
# Conference on Principles of Knowledge Representation and Reasoning, pp 557–
# 560
# Feng W, Zhang J, Dong Y , Han Y , Luan...
# ID: fddd8946-4c31-45eb-9221-7b5813f9c5b3 | Source: Continuous graph neural networks.pdf | Content: tional Joint Conference on Artificial Intelligence, pp 1373–1379
# Guo H, Tang R, Ye Y , Li Z, He X (2017) Deepfm: a factorization-machine based
# neural network for ctr prediction. In: Proceedings of the...
# ID: b3729066-f5d1-4560-9a8b-6221366b8cc3 | Source: Continuous graph neural networks.pdf | Content: References 631
# Kawahara J, Brown CJ, Miller SP, Booth BG, Chau V , Grunau RE, Zwicker JG,
# Hamarneh G (2017) Brainnetcnn: Convolutional neural networks for brain net-
# works; towards predicting neurodev...
# ID: 7bc56034-ed95-4dd7-8dc3-87e46384921b | Source: Continuous graph neural networks.pdf | Content: Proceedings of the Annual Meeting of the Cognitive Science Society, vol 32
# Lamb LC, Garcez A, Gori M, Prates M, Avelar P, Vardi M (2020) Graph neural
# networks meet neural-symbolic computing: A survey ...
# ID: d724671b-fd07-4a6a-85eb-0c2404dca875 | Source: Continuous graph neural networks.pdf | Content: Li Y , Lin Y , Madhusudan M, Sharma A, Xu W, Sapatnekar SS, Harjani R, Hu J
# (2020h) A customized graph neural network model for guiding analog ic place-
# ment. In: International Conference On Computer ...
# ID: 4b7d5542-0363-40d7-af96-c1062ea29d2b | Source: Continuous graph neural networks.pdf | Content: References 647
# ternational Symposium on Foundations of Software Engineering, ACM, pp 484–
# 495
# Morris C, Kersting K, Mutzel P (2017) Glocalized Weisfeiler-Lehman kernels:
# Global-local feature maps of g...
# ID: ffd1218d-3837-44ec-b556-1c0ba9540c1f | Source: Continuous graph neural networks.pdf | Content: ity methods for graph convolutional neural networks. In: Proceedings of the
# IEEE/CVF Conference on Computer Vision and Pattern Recognition, pp 10,772–
# 10,781
# Pradel M, Sen K (2018) Deepbugs: A learnin...
# ID: 5663b661-d281-433f-8a48-43326e32f0bf | Source: Deep learning in drug discovery_ an integrative review and future challenges.pdf | Content: sive similarity measures. BMC Bioinf 22:293. https:// doi. org/ 10. 1186/ s12859- 020- 03882-y
# Yifan D, Xinran X, Yang Q, Jingbo X, Wen Z, Shichao L (2020) A multimodal deep learning framework
# for pr...
# ID: f16b6146-7292-43cf-920a-b99aaaed905e | Source: Evaluating explainability for graph neural networks.pdf | Content: of a node u VG∈ .
# Graph neural networks. Most GNNs can be formulated as message passing networks39 using three operators:
# Msg, Agg, and Upd. In a L-layer GNN, these operators are recursively applied ...
# ID: bfe35f0b-9b7c-4020-99c8-97aab7e50414 | Source: Everything is connected_ Graph neural networks.pdf | Content: it into the TPUv5.
# Monti, F., Boscaini, D., Masci, J., Rodola, E., Svoboda, J., Bronstein, M.M., 2017.
# Geometric deep learning on graphs and manifolds using mixture model cnns, in:
# Proceedings of the ...
